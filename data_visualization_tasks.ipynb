# %%
import matplotlib.pyplot as plt

x = [1,2,3,4,5]
y = [2,4,6,8,10]

plt.plot(x,y)
plt.show()

# %%
plt.plot(x,y)
plt.xlabel("X values")
plt.ylabel("Y values")
plt.title("Simple Line Graph")
plt.show()

# %%
plt.plot(x,y,color='red',marker='o')
plt.title("Customized Line Plot")
plt.show()

# %%
hours=[1,2,3,4,5]
scores=[40,50,60,70,80]

plt.plot(hours,scores,marker='o')
plt.xlabel("Study Hours")
plt.ylabel("Exam Score")
plt.title("Study Hours vs Score")
plt.show()

# %%
days=[1,2,3,4,5]
temperature=[30,32,31,33,35]

plt.plot(days,temperature,marker='o')
plt.title("Temperature Trend")
plt.xlabel("Day")
plt.ylabel("Temperature")
plt.show()

# %%
months=["Jan","Feb","Mar","Apr"]
sales=[200,250,300,280]

plt.plot(months,sales,marker='o')
plt.title("Monthly Sales")
plt.show()

# %%
products=["A","B","C","D"]
values=[50,70,40,90]

plt.bar(products,values)
plt.title("Product Sales")
plt.show()

# %%
height=[150,160,165,170,180]
weight=[50,55,60,65,75]

plt.scatter(height,weight)
plt.title("Height vs Weight")
plt.xlabel("Height")
plt.ylabel("Weight")
plt.show()

# %%
years=[2020,2021,2022,2023]
profit=[10,15,20,25]

plt.plot(years,profit)
plt.title("Company Profit")
plt.show()

# %%
x=[1,2,3,4,5]
y=[2,3,5,7,11]

plt.scatter(x,y)
plt.title("Correlation Example")
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 import seaborn as sns
#       2 import matplotlib.pyplot as plt
#
# ModuleNotFoundError: No module named 'seaborn'

# %%
# !pip install seaborn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting seaborn
#   Downloading seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in C:\Users\WIN\AppData\Roaming\Python\Python313\site-packages (from seaborn) (2.4.2)
# Requirement already satisfied: pandas>=1.2 in C:\Users\WIN\AppData\Roaming\Python\Python313\site-packages (from seaborn) (2.3.3)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in C:\Users\WIN\AppData\Roaming\Python\Python313\site-packages (from seaborn) (3.10.8)
# Requirement already satisfied: contourpy>=1.0.1 in C:\Users\WIN\AppData\Roaming\Python\Python313\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in C:\Users\WIN\AppData\Roaming\Python\Python313\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in C:\Users\WIN\AppData\Roaming\Python\Python313\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.62.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in C:\Users\WIN\AppData\Roaming\Python\Python313\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in C:\Users\WIN\AppData\Roaming\Python\Python313\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (26.0)
# Requirement already satisfied: pillow>=8 in C:\Users\WIN\AppData\Roaming\Python\Python313\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (12.1.1)
# Requirement already satisfied: pyparsing>=3 in C:\Users\WIN\AppData\Roaming\Python\Python313\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in C:\Users\WIN\AppData\Roaming\Python\Python313\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in C:\Users\WIN\AppData\Roaming\Python\Python313\site-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in C:\Users\WIN\AppData\Roaming\Python\Python313\site-packages (from pandas>=1.2->seaborn) (2025.3)
# Requirement already satisfied: six>=1.5 in C:\Users\WIN\AppData\Roaming\Python\Python313\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.17.0)
# Downloading seaborn-0.13.2-py3-none-any.whl (294 kB)
# Installing collected packages: seaborn
# Successfully installed seaborn-0.13.2
# [notice] A new release of pip is available: 26.0.1 -> 26.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data=sns.load_dataset("tips")
data.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.barplot(x="day",y="total_bill",data=data)
plt.show()

# %%
sns.scatterplot(x="total_bill",y="tip",data=data)
plt.show()

# %%
iris=sns.load_dataset("iris")

sns.scatterplot(x="sepal_length",y="sepal_width",data=iris)
plt.show()

# %%
plt.scatter(iris["sepal_length"],iris["sepal_width"])
plt.title("Matplotlib Scatter")
plt.show()

# %%
import numpy as np

data=np.random.rand(5,5)
sns.heatmap(data)
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

iris = sns.load_dataset("iris")

corr = iris.select_dtypes(include='number').corr()

sns.heatmap(corr, annot=True)
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

tips = sns.load_dataset("tips")

sns.scatterplot(x="total_bill", y="tip", data=tips)

plt.title("Total Bill vs Tip")
plt.show()

# %%
plt.style.use("ggplot")
plt.plot([1,2,3],[4,5,6])
plt.title("Styled Plot")
plt.show()

# %%
plt.plot([1,2,3,4],[2,4,6,8])
plt.grid(True)
plt.show()

# %%
x=[1,2,3]
y=[10,20,15]

plt.plot(x,y,marker='o')
plt.annotate("Peak",(2,20))
plt.show()

# %%
plt.plot(x,y,color="green",linewidth=3)
plt.title("Custom Style")
plt.show()

# %%
import pandas as pd

data={
"Month":["Jan","Feb","Mar","Apr"],
"Sales":[200,250,300,280],
"Region":["North","South","East","West"]
}

df=pd.DataFrame(data)
df
# Out:
#   Month  Sales Region
# 0   Jan    200  North
# 1   Feb    250  South
# 2   Mar    300   East
# 3   Apr    280   West

# %%
plt.plot(df["Month"],df["Sales"],marker='o')
plt.title("Monthly Sales Trend")
plt.show()

# %%
plt.bar(df["Region"],df["Sales"])
plt.title("Sales by Region")
plt.show()

# %%
plt.scatter(df["Month"],df["Sales"])
plt.title("Sales Scatter")
plt.show()

# %%
sns.boxplot(x="Region",y="Sales",data=df)
plt.show()

# %%
corr=df.corr(numeric_only=True)
sns.heatmap(corr,annot=True)
plt.show()
